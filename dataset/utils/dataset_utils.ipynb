# %% [markdown]
# # Remove the headers from all files in a directory

# %%
import os
import csv

# Define the input and output folders
# CHANGE THIS ----↓
input_folder = "..."
output_folder = "..."

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Get the list of CSV files in the input folder
csv_files = [file for file in os.listdir(input_folder) if file.endswith(".csv")]

# Process each CSV file
for file in csv_files:
    input_file = os.path.join(input_folder, file)
    output_file = os.path.join(output_folder, file)

    # Read the input CSV file and remove the header
    with open(input_file, 'r') as f_input, open(output_file, 'w', newline='') as f_output:
        reader = csv.reader(f_input)
        writer = csv.writer(f_output)
        
        # Skip the header row
        next(reader)
        
        # Write the remaining rows to the output file
        writer.writerows(reader)

print("CSV files processed and headers removed.")

# %% [markdown]
# # Remove the header from one file

# %%
import pandas as pd

def remove_first_row(input_path, output_path):
    df = pd.read_csv(input_path)
    df = df.iloc[:, 1:]  # Remove the first row
    df.to_csv(output_path, index=False)

# CHANGE THIS --↓
input_path = "..."
output_path = "..."
remove_first_row(input_path, output_path)

# %% [markdown]
# # Combine multiple csv files from one folder into a single CSV file
# This was used when CenterSpeed dataset expected a single file.

# %%
import csv
import os
# CHANGE THIS --↓
output_file = '...'
input_dir = "..."

input_files = [os.path.join(input_dir, f) for f in os.listdir(input_dir) if os.path.isfile(os.path.join(input_dir, f))]
counter = 0

for i, file in enumerate(input_files):
    with open(file, 'r') as f:
        print("Total Entries in ", input_files[i], " :", sum(1 for line in f))

with open(output_file, 'a', newline='') as f:
    writer = csv.writer(f)
    for file_nr, file in enumerate(input_files):
        with open(file, 'r') as f_input:
            for row in csv.reader(f_input):
                if 'lidar' in row[0]:
                    continue # Skip the header
                row = [str(file_nr)] + row
                writer.writerow(row)
                counter += 1

with open(output_file, 'r') as f:
    print("Total Entries:", sum(1 for line in f))

print('Done!')
print('Total rows written:', counter)
# Out:
# Total Entries in  /home/f1tenth/catkin_ws/src/race_stack/perception/dataset/output/big_dataset/25_04_Dataset04_FTG_10s.csv  : 339
# Total Entries in  /home/f1tenth/catkin_ws/src/race_stack/perception/dataset/output/big_dataset/25_04_Dataset04_Fast_10s.csv  : 352
# Total Entries in  /home/f1tenth/catkin_ws/src/race_stack/perception/dataset/output/big_dataset/25_04_Dataset04_Manual_10s.csv  : 350
# Total Entries in  /home/f1tenth/catkin_ws/src/race_stack/perception/dataset/output/big_dataset/06_04_Dataset04_Front.csv  : 1281
# Total Entries in  /home/f1tenth/catkin_ws/src/race_stack/perception/dataset/output/big_dataset/25_04_Dataset03_Manual_10s.csv  : 353
# Total Entries in  /home/f1tenth/catkin_ws/src/race_stack/perception/dataset/output/big_dataset/25_04_Dataset03_10s.csv  : 353
# Total Entries in  /home/f1tenth/catkin_ws/src/race_stack/perception/dataset/output/big_dataset/25_04_Dataset02_Manual_10s.csv  : 353
# Total Entries in  /home/f1tenth/catkin_ws/src/race_stack/perception/dataset/output/big_dataset/25_04_Dataset01_FTG_10s.csv  : 344
# Total Entries in  /home/f1tenth/catkin_ws/src/race_stack/perception/dataset/output/big_dataset/25_04_Dataset03_FTG_10s.csv  : 354
# Total Entries in  /home/f1tenth/catkin_ws/src/race_stack/perception/dataset/output/big_dataset/06_04_Dataset03.csv  : 1281
# Total Entries in  /home/f1tenth/catkin_ws/src/race_stack/perception/dataset/output/big_dataset/25_04_Dataset01_10s.csv  : 358
# Total Entries in  /home/f1tenth/catkin_ws/src/race_stack/perception/dataset/output/big_dataset/25_04_Dataset01_Manual_10s.csv  : 354
# Total Entries in  /home/f1tenth/catkin_ws/src/race_stack/perception/dataset/output/big_dataset/06_04_Dataset04.csv  : 1281
# Total Entries in  /home/f1tenth/catkin_ws/src/race_stack/perception/dataset/output/big_dataset/25_04_Dataset04_10s.csv  : 353
# Total Entries in  /home/f1tenth/catkin_ws/src/race_stack/perception/dataset/output/big_dataset/25_04_Dataset02_10s.csv  : 353
# Total Entries in  /home/f1tenth/catkin_ws/src/race_stack/perception/dataset/output/big_dataset/06_04_Dataset02.csv  : 1281
# Total Entries in  /home/f1tenth/catkin_ws/src/race_stack/perception/dataset/output/big_dataset/25_04_Dataset02_FTG_10s.csv  : 352
# Total Entries in  /home/f1tenth/catkin_ws/src/race_stack/perception/dataset/output/big_dataset/06_04_Dataset02_Front.csv  : 401
# Total Entries in  /home/f1tenth/catkin_ws/src/race_stack/perception/dataset/output/big_dataset/06_04_Dataset05.csv  : 1281
# Total Entries in  /home/f1tenth/catkin_ws/src/race_stack/perception/dataset/output/big_dataset/06_04_Dataset03_Front.csv  : 1281
# Total Entries: 12635
# Done!
# Total rows written: 12635

# %% [markdown]
# # Data-augmentation on CSV level
# This was used before CenterSpeed dataset used transforms on a image-level.

# %%
import pandas as pd
import numpy as np
import csv

def augment(entry):
    entry['lidar'] = entry['lidar'].replace('(', '').replace(')', '')
    entry['intensities'] = entry['intensities'].replace('(', '').replace(')', '')
    lidar_data = np.fromstring(entry['lidar'], dtype=float, sep=', ', )
    intensities = np.fromstring(entry['intensities'], dtype=float, sep=',')
    lidar_data = np.flip(lidar_data)  # Reverse the lidar data
    intensities = np.flip(intensities)  # Reverse the intensities
    data = np.array(entry[3:])  # Extract the remaining data
    data[1] = -data[1]  # Reverse the y-coordinate
    data[3] = -data[3]  # Reverse the vy-coordinate
    data[4] = -data[4]  # Reverse the yaw
    
    return {'setid': entry['setid'], 'lidar': str(list(lidar_data)).replace('[','(').replace(']',')'), 'intensities': str(list(intensities)).replace('[','(').replace(']',')'),'x': data[0], 'y': data[1], 'vx': data[2], 'vy': data[3], 'yaw': data[4]}

# Change this --------↓
df = pd.read_csv('CSV_FILE_PATH', header=None, names=['setid', 'lidar', 'intensities', 'x', 'y', 'vx', 'vy', 'yaw'])
setn = df.max()['setid']
df.to_csv('5_combined_aug.csv', index=False)
fieldnames = ['setid','lidar', 'intensities', 'x', 'y', 'vx', 'vy', 'yaw']
df.columns = ['setid', 'lidar', 'intensities', 'x','y','vx','vy','yaw']
print("Initial length: ",len(df))

# Randomly select some entries
#num_entries_to_augment =  len(df)//2
entries_to_augment = df#df.sample(num_entries_to_augment)
augmented_entries = []
for index,entry in entries_to_augment.iterrows():
    entry['setid'] = int(entry['setid']) + setn + 1
    augmented_entry = augment(entry)
    augmented_entries.append(augmented_entry)
    print(entry)

# Change this ↓
with open('OUTPUT_FILE_PATH', mode='a', newline='') as file:
            # Create a DictWriter object, specifying the file and the fieldnames
            writer = csv.DictWriter(file, fieldnames=fieldnames)
    
    
            # Write the data rows to the CSV file
            for i, row in enumerate(augmented_entries):
                writer.writerow(row)

df_test = pd.read_csv('OUTPUT_FILE_PATH')
print(len(df_test))
# Out:
# Initial length:  6348
# setid                                                          5
# lidar          0.06499999761581421, 0.057999998331069946, 0.0...
# intensities    550.0, 526.0, 497.0, 455.0, 421.0, 540.0, 540....
# x                                                       0.895224
# y                                                       0.881535
# vx                                                      0.745468
# vy                                                     -1.698698
# yaw                                                     1.157256
# Name: 0, dtype: object
# setid                                                          5
# lidar          0.06400000303983688, 0.07400000095367432, 0.05...
# intensities    546.0, 536.0, 507.0, 463.0, 446.0, 542.0, 595....
# x                                                       0.911195
# y                                                       0.840821
# vx                                                      0.748953
# vy                                                     -1.740895
# yaw                                                      1.16452
# Name: 1, dtype: object
# setid                                                          5
# lidar          0.06400000303983688, 0.07400000095367432, 0.05...
# intensities    546.0, 536.0, 507.0, 463.0, 446.0, 542.0, 595....
# x                                                       0.950696
# y                                                       0.860927
# vx                                                      0.760025
# vy                                                     -1.779022
# yaw                                                     1.167051
# Name: 2, dtype: object
# setid                                                          5
# lidar          0.07000000029802322, 0.05999999865889549, 0.05...
# intensities    560.0, 524.0, 506.0, 464.0, 427.0, 568.0, 570....
# x                                                       0.940642
# y                                                       0.812125
# vx                                                      0.822318
# vy                                                       -1.7511
# yaw                                                     1.131762
# Name: 3, dtype: object
# setid                                                          5
# lidar          0.06400000303983688, 0.06199999898672104, 0.04...
# intensities    555.0, 527.0, 480.0, 476.0, 407.0, 570.0, 572....
# x                                                       0.974767
# y                                                       0.821351
# vx                                                      0.927322
# vy                                                     -1.727774
# yaw                                                      1.07821
# Name: 4, dtype: object
# setid                                                          5
# lidar          0.054999999701976776, 0.06800000369548798, 0.0...
# intensities    533.0, 530.0, 516.0, 468.0, 422.0, 566.0, 561....
# x                                                       0.961623
# y                                                        0.76691
# vx                                                      0.927322
# vy                                                     -1.727774
# yaw                                                      1.07821
# Name: 5, dtype: object
# setid                                                          5
# lidar          0.054999999701976776, 0.06800000369548798, 0.0...
# intensities    533.0, 530.0, 516.0, 468.0, 422.0, 566.0, 561....
# x                                                       0.960616
# y                                                       0.779624
# vx                                                      1.009193
# vy                                                     -1.718702
# yaw                                                     1.039854
# Name: 6, dtype: object
# setid                                                          5
# lidar          0.05700000002980232, 0.057999998331069946, 0.0...
# intensities    550.0, 522.0, 490.0, 445.0, 436.0, 534.0, 569....
# x                                                       0.974479
# y                                                       0.814634
# vx                                                      1.023081
# vy                                                     -1.718351
# yaw                                                     1.033777
# Name: 7, dtype: object
# setid                                                          5
# lidar          0.05700000002980232, 0.057999998331069946, 0.0...
# intensities    550.0, 522.0, 490.0, 445.0, 436.0, 534.0, 569....
# x                                                       0.987568
# y                                                       0.825406
# vx                                                      0.958913
# vy                                                     -1.704957
# yaw                                                     1.058463
# Name: 8, dtype: object
# setid                                                          5
# lidar          0.0689999982714653, 0.06800000369548798, 0.068...
# intensities    547.0, 523.0, 494.0, 459.0, 431.0, 626.0, 629....
# x                                                       1.013781
# y                                                       0.824779
# vx                                                        1.0212
# vy                                                     -1.729874
# yaw                                                     1.037516
# Name: 9, dtype: object
# setid                                                          5
# lidar          0.06700000166893005, 0.05999999865889549, 0.06...
# intensities    556.0, 528.0, 494.0, 478.0, 420.0, 578.0, 583....
# x                                                       1.049119
# y                                                       0.780981
# vx                                                      1.148653
# vy                                                     -1.648003
# yaw                                                     0.962089
# Name: 10, dtype: object
# setid                                                          5
# lidar          0.06700000166893005, 0.05999999865889549, 0.06...
# intensities    556.0, 528.0, 494.0, 478.0, 420.0, 578.0, 583....
# x                                                       1.049297
# y                                                        0.79417
# vx                                                      1.105874
# vy                                                     -1.661389
# yaw                                                      0.98351
# Name: 11, dtype: object
# setid                                                          5
# lidar          0.06700000166893005, 0.054999999701976776, 0.0...
# intensities    549.0, 523.0, 516.0, 466.0, 436.0, 634.0, 702....
# x                                                       1.070288
# y                                                       0.739298
# vx                                                      1.274372
# vy                                                     -1.535951
# yaw                                                     0.878209
# Name: 12, dtype: object
# setid                                                          5
# lidar          0.06700000166893005, 0.054999999701976776, 0.0...
# intensities    549.0, 523.0, 516.0, 466.0, 436.0, 634.0, 702....
# x                                                       1.084148
# y                                                       0.742587
# vx                                                      1.239217
# vy                                                     -1.597201
# yaw                                                     0.910944
# Name: 13, dtype: object
# setid                                                          5
# lidar          0.057999998331069946, 0.06300000101327896, 0.0...
# intensities    554.0, 540.0, 502.0, 488.0, 438.0, 404.0, 712....
# x                                                        1.10948
# y                                                        0.70211
# vx                                                      1.333639
# vy                                                     -1.521548
# yaw                                                     0.851116
# Name: 14, dtype: object
# setid                                                          5
# lidar          0.057999998331069946, 0.06300000101327896, 0.0...
# intensities    554.0, 540.0, 502.0, 488.0, 438.0, 404.0, 712....
# x                                                       1.110182
# y                                                       0.706489
# vx                                                      1.318146
# vy                                                     -1.534989
# yaw                                                     0.861254
# Name: 15, dtype: object
# setid                                                          5
# lidar          0.06199999898672104, 0.05000000074505806, 0.06...
# intensities    544.0, 522.0, 508.0, 468.0, 424.0, 615.0, 630....
# x                                                       1.171707
# y                                                       0.666006
# vx                                                      1.486636
# vy                                                     -1.508291
# yaw                                                     0.792629
# Name: 16, dtype: object
# setid                                                          5
# lidar          0.06199999898672104, 0.07000000029802322, 0.05...
# intensities    555.0, 521.0, 496.0, 466.0, 416.0, 600.0, 669....
# x                                                       1.145572
# y                                                       0.601222
# vx                                                      1.516555
# vy                                                     -1.592387
# yaw                                                     0.809785
# Name: 17, dtype: object
# setid                                                          5
# lidar          0.06199999898672104, 0.07000000029802322, 0.05...
# intensities    555.0, 521.0, 496.0, 466.0, 416.0, 600.0, 669....
# x                                                       1.145572
# y                                                       0.601222
# vx                                                      1.663882
# vy                                                     -1.437753
# yaw                                                      0.71262
# Name: 18, dtype: object
# setid                                                          5
# lidar          0.06599999964237213, 0.06400000303983688, 0.06...
# intensities    556.0, 524.0, 507.0, 468.0, 443.0, 564.0, 580....
# x                                                       1.216937
# y                                                       0.583738
# vx                                                      1.673918
# vy                                                     -1.441396
# yaw                                                     0.710898
# Name: 19, dtype: object
# setid                                                          5
# lidar          0.06599999964237213, 0.06400000303983688, 0.06...
# intensities    556.0, 524.0, 507.0, 468.0, 443.0, 564.0, 580....
# x                                                       1.216937
# y                                                       0.583738
# vx                                                      1.722383
# vy                                                     -1.383119
# yaw                                                     0.676584
# Name: 20, dtype: object
# setid                                                          5
# lidar          0.06700000166893005, 0.050999999046325684, 0.0...
# intensities    564.0, 519.0, 497.0, 474.0, 418.0, 401.0, 821....
# x                                                        1.27273
# y                                                       0.549478
# vx                                                      1.804518
# vy                                                     -1.361907
# yaw                                                     0.646515
# Name: 21, dtype: object
# setid                                                          5
# lidar          0.06700000166893005, 0.050999999046325684, 0.0...
# intensities    564.0, 519.0, 497.0, 474.0, 418.0, 401.0, 821....
# x                                                        1.27273
# y                                                       0.549478
# vx                                                      1.905295
# vy                                                     -1.216933
# yaw                                                     0.568398
# Name: 22, dtype: object
# setid                                                          5
# lidar          0.06599999964237213, 0.061000000685453415, 0.0...
# intensities    566.0, 534.0, 505.0, 461.0, 417.0, 609.0, 605....
# x                                                       1.269966
# y                                                       0.487673
# vx                                                      1.985247
# vy                                                     -1.311885
# yaw                                                     0.583942
# Name: 23, dtype: object
# setid                                                          5
# lidar          0.06599999964237213, 0.061000000685453415, 0.0...
# intensities    566.0, 534.0, 505.0, 461.0, 417.0, 609.0, 605....
# x                                                       1.269966
# y                                                       0.487673
# vx                                                      2.054608
# vy                                                     -1.200346
# yaw                                                     0.528737
# Name: 24, dtype: object
# setid                                                          5
# lidar          0.06400000303983688, 0.06300000101327896, 0.06...
# intensities    553.0, 525.0, 507.0, 478.0, 431.0, 417.0, 573....
# x                                                       1.340429
# y                                                       0.505156
# vx                                                      2.002691
# vy                                                     -1.239612
# yaw                                                     0.554254
# Name: 25, dtype: object
# setid                                                          5
# lidar          0.06400000303983688, 0.06300000101327896, 0.06...
# intensities    553.0, 525.0, 507.0, 478.0, 431.0, 417.0, 573....
# x                                                       1.340429
# y                                                       0.505156
# vx                                                      2.056856
# vy                                                     -1.147497
# yaw                                                      0.50888
# Name: 26, dtype: object
# setid                                                          5
# lidar          0.06300000101327896, 0.0560000017285347, 0.064...
# intensities    558.0, 532.0, 508.0, 470.0, 431.0, 546.0, 534....
# x                                                       1.326492
# y                                                       0.475404
# vx                                                      2.005067
# vy                                                     -1.142994
# yaw                                                     0.518108
# Name: 27, dtype: object
# setid                                                          5
# lidar          0.06300000101327896, 0.0560000017285347, 0.064...
# intensities    558.0, 532.0, 508.0, 470.0, 431.0, 546.0, 534....
# x                                                       1.326492
# y                                                       0.475404
# vx                                                      2.021911
# vy                                                     -1.069342
# yaw                                                     0.486481
# Name: 28, dtype: object
# setid                                                          5
# lidar          0.05999999865889549, 0.06800000369548798, 0.05...
# intensities    555.0, 538.0, 502.0, 463.0, 442.0, 626.0, 576....
# x                                                       1.392264
# y                                                       0.501169
# vx                                                      1.976229
# vy                                                     -1.062526
# yaw                                                     0.493315
# Name: 29, dtype: object
# setid                                                          5
# lidar          0.05000000074505806, 0.06499999761581421, 0.05...
# intensities    542.0, 519.0, 494.0, 451.0, 434.0, 711.0, 584....
# x                                                       1.402499
# y                                                       0.483955
# vx                                                      1.999412
# vy                                                     -1.018233
# yaw                                                     0.471033
# Name: 30, dtype: object
# setid                                                          5
# lidar          0.05000000074505806, 0.06499999761581421, 0.05...
# intensities    542.0, 519.0, 494.0, 451.0, 434.0, 711.0, 584....
# x                                                       1.402499
# y                                                       0.483955
# vx                                                      1.999412
# vy                                                     -1.018233
# yaw                                                     0.471033
# Name: 31, dtype: object
# setid                                                          5
# lidar          0.06800000369548798, 0.061000000685453415, 0.0...
# intensities    540.0, 528.0, 505.0, 450.0, 431.0, 528.0, 560....
# x                                                       1.389221
# y                                                       0.454273
# vx                                                      1.981022
# vy                                                     -0.969975
# yaw                                                      0.45532
# Name: 32, dtype: object
# setid                                                          5
# lidar          0.06800000369548798, 0.061000000685453415, 0.0...
# intensities    540.0, 528.0, 505.0, 450.0, 431.0, 528.0, 560....
# x                                                       1.389221
# y                                                       0.454273
# vx                                                      1.990325
# vy                                                     -0.993001
# yaw                                                     0.462779
# Name: 33, dtype: object
# setid                                                          5
# lidar          0.07000000029802322, 0.05900000035762787, 0.05...
# intensities    558.0, 518.0, 508.0, 461.0, 422.0, 676.0, 576....
# x                                                       1.444927
# y                                                       0.488939
# vx                                                      2.000277
# vy                                                     -0.942974
# yaw                                                     0.440525
# Name: 34, dtype: object
# setid                                                          5
# lidar          0.07000000029802322, 0.05900000035762787, 0.05...
# intensities    558.0, 518.0, 508.0, 461.0, 422.0, 676.0, 576....
# x                                                       1.444927
# y                                                       0.488939
# vx                                                      2.000277
# vy                                                     -0.942974
# yaw                                                     0.440525
# Name: 35, dtype: object
# setid                                                          5
# lidar          0.06800000369548798, 0.06700000166893005, 0.06...
# intensities    545.0, 535.0, 498.0, 445.0, 458.0, 543.0, 546....
# x                                                       1.441887
# y                                                        0.48436
# vx                                                      1.990157
# vy                                                     -0.964732
# yaw                                                     0.451375
# Name: 36, dtype: object
# setid                                                          5
# lidar          0.06800000369548798, 0.06700000166893005, 0.06...
# intensities    545.0, 535.0, 498.0, 445.0, 458.0, 543.0, 546....
# x                                                       1.441887
# y                                                        0.48436
# vx                                                      1.990157
# vy                                                     -0.964732
# yaw                                                     0.451375
# Name: 37, dtype: object
# setid                                                          5
# lidar          0.06700000166893005, 0.06599999964237213, 0.05...
# intensities    554.0, 530.0, 502.0, 473.0, 432.0, 562.0, 572....
# x                                                        1.42852
# y                                                       0.476663
# vx                                                      1.896372
# vy                                                     -0.938813
# yaw                                                     0.459685
# Name: 38, dtype: object
# setid                                                          5
# lidar          0.052000001072883606, 0.06800000369548798, 0.0...
# intensities    547.0, 543.0, 499.0, 472.0, 429.0, 547.0, 548....
# x                                                       1.432711
# y                                                       0.476702
# vx                                                      1.896372
# vy                                                     -0.938813
# yaw                                                     0.459685
# Name: 39, dtype: object
# setid                                                          5
# lidar          0.052000001072883606, 0.06800000369548798, 0.0...
# intensities    547.0, 543.0, 499.0, 472.0, 429.0, 547.0, 548....
# x                                                       1.432711
# y                                                       0.476702
# vx                                                      1.898782
# vy                                                     -0.911575
# yaw                                                     0.447588
# Name: 40, dtype: object
# setid                                                          5
# lidar          0.06599999964237213, 0.06199999898672104, 0.07...
# intensities    547.0, 525.0, 517.0, 464.0, 416.0, 585.0, 565....
# x                                                       1.419172
# y                                                       0.473452
# vx                                                      1.898782
# vy                                                     -0.911575
# yaw                                                     0.447588
# Name: 41, dtype: object
# setid                                                          5
# lidar          0.06599999964237213, 0.06199999898672104, 0.07...
# intensities    547.0, 525.0, 517.0, 464.0, 416.0, 585.0, 565....
# x                                                       1.419172
# y                                                       0.473452
# vx                                                      1.838852
# vy                                                      -0.86648
# yaw                                                     0.440349
# Name: 42, dtype: object
# setid                                                          5
# lidar          0.0689999982714653, 0.05999999865889549, 0.056...
# intensities    569.0, 532.0, 510.0, 463.0, 435.0, 502.0, 475....
# x                                                       1.407183
# y                                                       0.455028
# vx                                                      1.838852
# vy                                                      -0.86648
# yaw                                                     0.440349
# Name: 43, dtype: object
# setid                                                          5
# lidar          0.0689999982714653, 0.05999999865889549, 0.056...
# intensities    569.0, 532.0, 510.0, 463.0, 435.0, 502.0, 475....
# x                                                       1.407183
# y                                                       0.455028
# vx                                                      1.816179
# vy                                                     -0.848165
# yaw                                                     0.436905
# Name: 44, dtype: object
# setid                                                          5
# lidar          0.07699999958276749, 0.05700000002980232, 0.07...
# intensities    559.0, 524.0, 514.0, 473.0, 425.0, 614.0, 614....
# x                                                       1.385969
# y                                                       0.437277
# vx                                                      1.781633
# vy                                                     -0.881732
# yaw                                                      0.45956
# Name: 45, dtype: object
# setid                                                          5
# lidar          0.07699999958276749, 0.05700000002980232, 0.07...
# intensities    559.0, 524.0, 514.0, 473.0, 425.0, 614.0, 614....
# x                                                       1.385969
# y                                                       0.437277
# vx                                                      1.815066
# vy                                                     -0.810681
# yaw                                                     0.420056
# Name: 46, dtype: object
# setid                                                          5
# lidar          0.05000000074505806, 0.0689999982714653, 0.057...
# intensities    548.0, 519.0, 497.0, 471.0, 408.0, 539.0, 571....
# x                                                       1.378503
# y                                                       0.433337
# vx                                                      1.832386
# vy                                                     -0.790014
# yaw                                                     0.407059
# Name: 47, dtype: object
# setid                                                          5
# lidar          0.05000000074505806, 0.0689999982714653, 0.057...
# intensities    548.0, 519.0, 497.0, 471.0, 408.0, 539.0, 571....
# x                                                       1.378503
# y                                                       0.433337
# vx                                                      1.841259
# vy                                                     -0.769106
# yaw                                                     0.395677
# Name: 48, dtype: object
# setid                                                          5
# lidar          0.05299999937415123, 0.05900000035762787, 0.06...
# intensities    546.0, 536.0, 509.0, 468.0, 423.0, 633.0, 638....
# x                                                       1.355265
# y                                                       0.415346
# vx                                                      1.764234
# vy                                                     -0.800273
# yaw                                                     0.425851
# Name: 49, dtype: object
# setid                                                          5
# lidar          0.05999999865889549, 0.05999999865889549, 0.04...
# intensities    551.0, 540.0, 484.0, 484.0, 412.0, 581.0, 553....
# x                                                       1.339977
# y                                                       0.365635
# vx                                                       1.78213
# vy                                                     -0.759585
# yaw                                                     0.402906
# Name: 50, dtype: object
# setid                                                          5
# lidar          0.05999999865889549, 0.05999999865889549, 0.04...
# intensities    551.0, 540.0, 484.0, 484.0, 412.0, 581.0, 553....
# x                                                       1.339977
# y                                                       0.365635
# vx                                                       1.75329
# vy                                                     -0.729314
# yaw                                                     0.394196
# Name: 51, dtype: object
# setid                                                          5
# lidar          0.050999999046325684, 0.06199999898672104, 0.0...
# intensities    544.0, 542.0, 499.0, 474.0, 456.0, 451.0, 503....
# x                                                       1.337201
# y                                                       0.319021
# vx                                                       1.75329
# vy                                                     -0.729314
# yaw                                                     0.394196
# Name: 52, dtype: object
# setid                                                          5
# lidar          0.050999999046325684, 0.06199999898672104, 0.0...
# intensities    544.0, 542.0, 499.0, 474.0, 456.0, 451.0, 503....
# x                                                       1.337201
# y                                                       0.319021
# vx                                                      1.772182
# vy                                                     -0.654933
# yaw                                                     0.353995
# Name: 53, dtype: object
# setid                                                          5
# lidar          0.057999998331069946, 0.0689999982714653, 0.05...
# intensities    550.0, 544.0, 483.0, 458.0, 410.0, 614.0, 729....
# x                                                       1.314246
# y                                                       0.295135
# vx                                                      1.776564
# vy                                                     -0.642951
# yaw                                                     0.347243
# Name: 54, dtype: object
# setid                                                          5
# lidar          0.057999998331069946, 0.0689999982714653, 0.05...
# intensities    550.0, 544.0, 483.0, 458.0, 410.0, 614.0, 729....
# x                                                       1.314246
# y                                                       0.295135
# vx                                                      1.771219
# vy                                                     -0.676896
# yaw                                                     0.365036
# Name: 55, dtype: object
# setid                                                          5
# lidar          0.07000000029802322, 0.05999999865889549, 0.05...
# intensities    553.0, 529.0, 487.0, 449.0, 610.0, 610.0, 640....
# x                                                       1.300582
# y                                                       0.283282
# vx                                                      1.771219
# vy                                                     -0.676896
# yaw                                                     0.365036
# Name: 56, dtype: object
# setid                                                          5
# lidar          0.057999998331069946, 0.06400000303983688, 0.0...
# intensities    550.0, 530.0, 505.0, 1088.0, 777.0, 820.0, 768...
# x                                                       1.288921
# y                                                       0.249881
# vx                                                      1.727377
# vy                                                     -0.687877
# yaw                                                     0.378971
# Name: 57, dtype: object
# setid                                                          5
# lidar          0.057999998331069946, 0.06400000303983688, 0.0...
# intensities    550.0, 530.0, 505.0, 1088.0, 777.0, 820.0, 768...
# x                                                       1.288921
# y                                                       0.249881
# vx                                                      1.727377
# vy                                                     -0.687877
# yaw                                                     0.378971
# Name: 58, dtype: object
# setid                                                          5
# lidar          0.15600000321865082, 0.2240000069141388, 0.333...
# intensities    726.0, 809.0, 1043.0, 1081.0, 1051.0, 1067.0, ...
# x                                                       1.256105
# y                                                       0.235578
# vx                                                      1.694638
# vy                                                     -0.638225
# yaw                                                     0.360185
# Name: 59, dtype: object
# setid                                                          5
# lidar          0.15600000321865082, 0.2240000069141388, 0.333...
# intensities    726.0, 809.0, 1043.0, 1081.0, 1051.0, 1067.0, ...
# x                                                       1.256105
# y                                                       0.235578
# vx                                                      1.694638
# vy                                                     -0.638225
# yaw                                                     0.360185
# Name: 60, dtype: object
# setid                                                          5
# lidar          0.16599999368190765, 0.15000000596046448, 0.24...
# intensities    748.0, 708.0, 834.0, 1077.0, 1131.0, 880.0, 81...
# x                                                        1.24706
# y                                                       0.218244
# vx                                                      1.725669
# vy                                                     -0.645104
# yaw                                                     0.357743
# Name: 61, dtype: object
# setid                                                          5
# lidar          0.16599999368190765, 0.15000000596046448, 0.24...
# intensities    748.0, 708.0, 834.0, 1077.0, 1131.0, 880.0, 81...
# x                                                        1.24706
# y                                                       0.218244
# vx                                                      1.725669
# vy                                                     -0.645104
# yaw                                                     0.357743
# Name: 62, dtype: object
# setid                                                          5
# lidar          0.09799999743700027, 0.13699999451637268, 0.15...
# intensities    610.0, 665.0, 670.0, 725.0, 811.0, 865.0, 861....
# x                                                       1.207376
# y                                                       0.190813
# vx                                                      1.738484
# vy                                                     -0.673605
# yaw                                                     0.369656
# Name: 63, dtype: object
# setid                                                          5
# lidar          0.09799999743700027, 0.13699999451637268, 0.15...
# intensities    610.0, 665.0, 670.0, 725.0, 811.0, 865.0, 861....
# x                                                       1.207376
# y                                                       0.190813
# vx                                                      1.738484
# vy                                                     -0.673605
# yaw                                                     0.369656
# Name: 64, dtype: object
# setid                                                          5
# lidar          0.13500000536441803, 0.22100000083446503, 0.24...
# intensities    679.0, 805.0, 810.0, 963.0, 1162.0, 1100.0, 99...
# x                                                        1.21015
# y                                                        0.23998
# vx                                                      1.717911
# vy                                                     -0.670473
# yaw                                                     0.372103
# Name: 65, dtype: object
# setid                                                          5
# lidar          0.11599999666213989, 0.2639999985694885, 0.216...
# intensities    643.0, 911.0, 788.0, 941.0, 1115.0, 1033.0, 10...
# x                                                        1.16215
# y                                                       0.224239
# vx                                                      1.729557
# vy                                                     -0.639831
# yaw                                                     0.354327
# Name: 66, dtype: object
# setid                                                          5
# lidar          0.11599999666213989, 0.2639999985694885, 0.216...
# intensities    643.0, 911.0, 788.0, 941.0, 1115.0, 1033.0, 10...
# x                                                        1.16215
# y                                                       0.224239
# vx                                                       1.68638
# vy                                                     -0.714958
# yaw                                                     0.400989
# Name: 67, dtype: object
# setid                                                          5
# lidar          0.1340000033378601, 0.19599999487400055, 0.270...
# intensities    688.0, 764.0, 880.0, 942.0, 1021.0, 1068.0, 99...
# x                                                       1.173928
# y                                                       0.278563
# vx                                                       1.69475
# vy                                                     -0.694885
# yaw                                                     0.389116
# Name: 68, dtype: object
# setid                                                          5
# lidar          0.1340000033378601, 0.19599999487400055, 0.270...
# intensities    688.0, 764.0, 880.0, 942.0, 1021.0, 1068.0, 99...
# x                                                       1.173928
# y                                                       0.278563
# vx                                                      1.673685
# vy                                                     -0.773984
# yaw                                                     0.433153
# Name: 69, dtype: object
# setid                                                          5
# lidar          0.11900000274181366, 0.16200000047683716, 0.28...
# intensities    638.0, 702.0, 898.0, 965.0, 871.0, 759.0, 946....
# x                                                       1.138368
# y                                                       0.319801
# vx                                                      1.668443
# vy                                                     -0.792644
# yaw                                                     0.443513
# Name: 70, dtype: object
# setid                                                          5
# lidar          0.11900000274181366, 0.16200000047683716, 0.28...
# intensities    638.0, 702.0, 898.0, 965.0, 871.0, 759.0, 946....
# x                                                       1.138368
# y                                                       0.319801
# vx                                                      1.668443
# vy                                                     -0.792644
# yaw                                                     0.443513
# Name: 71, dtype: object
# setid                                                          5
# lidar          0.14000000059604645, 0.17499999701976776, 0.24...
# intensities    674.0, 689.0, 815.0, 1045.0, 930.0, 1084.0, 96...
# x                                                       1.094587
# y                                                       0.318869
# vx                                                      1.636754
# vy                                                     -0.864333
# yaw                                                     0.485857
# Name: 72, dtype: object
# setid                                                          5
# lidar          0.14000000059604645, 0.17499999701976776, 0.24...
# intensities    674.0, 689.0, 815.0, 1045.0, 930.0, 1084.0, 96...
# x                                                       1.094587
# y                                                       0.318869
# vx                                                      1.585442
# vy                                                     -0.931026
# yaw                                                      0.53098
# Name: 73, dtype: object
# setid                                                          5
# lidar          0.19900000095367432, 0.23199999332427979, 0.26...
# intensities    779.0, 820.0, 874.0, 1045.0, 1183.0, 1141.0, 1...
# x                                                       1.115112
# y                                                        0.37521
# vx                                                      1.590357
# vy                                                     -0.922605
# yaw                                                     0.525677
# Name: 74, dtype: object
# setid                                                          5
# lidar          0.09600000083446503, 0.14399999380111694, 0.20...
# intensities    603.0, 658.0, 762.0, 797.0, 786.0, 912.0, 885....
# x                                                       1.035921
# y                                                       0.384774
# vx                                                      1.582808
# vy                                                     -1.033705
# yaw                                                      0.57854
# Name: 75, dtype: object
# setid                                                          5
# lidar          0.09600000083446503, 0.14399999380111694, 0.20...
# intensities    603.0, 658.0, 762.0, 797.0, 786.0, 912.0, 885....
# x                                                       1.035921
# y                                                       0.384774
# vx                                                      1.562409
# vy                                                     -1.064287
# yaw                                                     0.597986
# Name: 76, dtype: object
# setid                                                          5
# lidar          0.1080000028014183, 0.16899999976158142, 0.193...
# intensities    637.0, 712.0, 739.0, 772.0, 759.0, 798.0, 917....
# x                                                       1.057438
# y                                                       0.462341
# vx                                                      1.490235
# vy                                                     -1.099877
# yaw                                                     0.635813
# Name: 77, dtype: object
# setid                                                          5
# lidar          0.1080000028014183, 0.16899999976158142, 0.193...
# intensities    637.0, 712.0, 739.0, 772.0, 759.0, 798.0, 917....
# x                                                       1.057438
# y                                                       0.462341
# vx                                                      1.509279
# vy                                                     -1.073594
# yaw                                                     0.618289
# Name: 78, dtype: object
# setid                                                          5
# lidar          0.08500000089406967, 0.17800000309944153, 0.17...
# intensities    579.0, 736.0, 697.0, 848.0, 970.0, 995.0, 986....
# x                                                       0.977414
# y                                                       0.452914
# vx                                                      1.444729
# vy                                                       -1.1306
# yaw                                                     0.664021
# Name: 79, dtype: object
# setid                                                          5
# lidar          0.08500000089406967, 0.17800000309944153, 0.17...
# intensities    579.0, 736.0, 697.0, 848.0, 970.0, 995.0, 986....
# x                                                       0.977414
# y                                                       0.452914
# vx                                                       1.45869
# vy                                                     -1.112528
# yaw                                                     0.651573
# Name: 80, dtype: object
# setid                                                          5
# lidar          0.10300000011920929, 0.12800000607967377, 0.17...
# intensities    611.0, 656.0, 703.0, 813.0, 1039.0, 917.0, 965...
# x                                                       0.978893
# y                                                       0.455568
# vx                                                      1.410856
# vy                                                     -1.216737
# yaw                                                     0.711655
# Name: 81, dtype: object
# setid                                                          5
# lidar          0.10300000011920929, 0.12800000607967377, 0.17...
# intensities    611.0, 656.0, 703.0, 813.0, 1039.0, 917.0, 965...
# x                                                       0.978893
# y                                                       0.455568
# vx                                                      1.441415
# vy                                                     -1.180376
# yaw                                                      0.68616
# Name: 82, dtype: object
# setid                                                          5
# lidar          0.12300000339746475, 0.15600000321865082, 0.20...
# intensities    656.0, 681.0, 736.0, 911.0, 939.0, 885.0, 893....
# x                                                       1.015501
# y                                                       0.514372
# vx                                                      1.320644
# vy                                                     -1.253227
# yaw                                                     0.759211
# Name: 83, dtype: object
# setid                                                          5
# lidar          0.12399999797344208, 0.24699999392032623, 0.26...
# intensities    653.0, 872.0, 874.0, 1106.0, 942.0, 995.0, 949...
# x                                                       0.983913
# y                                                        0.52245
# vx                                                      1.387752
# vy                                                     -1.178483
# yaw                                                     0.704031
# Name: 84, dtype: object
# setid                                                          5
# lidar          0.12399999797344208, 0.24699999392032623, 0.26...
# intensities    653.0, 872.0, 874.0, 1106.0, 942.0, 995.0, 949...
# x                                                       1.004264
# y                                                       0.522188
# vx                                                      1.283997
# vy                                                     -1.198522
# yaw                                                     0.750981
# Name: 85, dtype: object
# setid                                                          5
# lidar          0.11299999803304672, 0.20600000023841858, 0.35...
# intensities    629.0, 781.0, 1055.0, 926.0, 1111.0, 1182.0, 1...
# x                                                       0.979083
# y                                                       0.534265
# vx                                                      1.318771
# vy                                                     -1.160148
# yaw                                                     0.721496
# Name: 86, dtype: object
# setid                                                          5
# lidar          0.11299999803304672, 0.20600000023841858, 0.35...
# intensities    629.0, 781.0, 1055.0, 926.0, 1111.0, 1182.0, 1...
# x                                                       0.993343
# y                                                       0.535113
# vx                                                      1.275498
# vy                                                     -1.259066
# yaw                                                     0.778915
# Name: 87, dtype: object
# setid                                                          5
# ...
# vy                                                      1.658385
# yaw                                                    -1.036516
# Name: 6318, dtype: object
# setid                                                          9
# lidar          0.08699999749660492, 0.13500000536441803, 0.14...
# intensities    587.0, 642.0, 650.0, 861.0, 992.0, 998.0, 963....
# x                                                       1.276169
# y                                                      -1.025283
# vx                                                      0.941724
# vy                                                      1.634087
# yaw                                                    -1.047986
# Name: 6319, dtype: object
# setid                                                          9
# lidar          0.08699999749660492, 0.13500000536441803, 0.14...
# intensities    587.0, 642.0, 650.0, 861.0, 992.0, 998.0, 963....
# x                                                       1.276169
# y                                                      -1.025283
# vx                                                       1.04725
# vy                                                      1.568552
# yaw                                                     -0.98211
# Name: 6320, dtype: object
# setid                                                          9
# lidar          0.10000000149011612, 0.1509999930858612, 0.230...
# intensities    616.0, 662.0, 797.0, 856.0, 922.0, 884.0, 901....
# x                                                       1.313447
# y                                                       -0.95785
# vx                                                      0.991455
# vy                                                      1.659377
# yaw                                                    -1.032227
# Name: 6321, dtype: object
# setid                                                          9
# lidar          0.10000000149011612, 0.1509999930858612, 0.230...
# intensities    616.0, 662.0, 797.0, 856.0, 922.0, 884.0, 901....
# x                                                       1.313447
# y                                                       -0.95785
# vx                                                      1.130681
# vy                                                      1.567825
# yaw                                                    -0.945998
# Name: 6322, dtype: object
# setid                                                          9
# lidar          0.07199999690055847, 0.1589999943971634, 0.212...
# intensities    578.0, 685.0, 754.0, 882.0, 846.0, 868.0, 953....
# x                                                       1.329211
# y                                                      -0.896318
# vx                                                      1.016612
# vy                                                      1.594254
# yaw                                                    -1.003136
# Name: 6323, dtype: object
# setid                                                          9
# lidar          0.07199999690055847, 0.1589999943971634, 0.212...
# intensities    578.0, 685.0, 754.0, 882.0, 846.0, 868.0, 953....
# x                                                       1.329211
# y                                                      -0.896318
# vx                                                      1.127227
# vy                                                      1.500939
# yaw                                                    -0.926646
# Name: 6324, dtype: object
# setid                                                          9
# lidar          0.08799999952316284, 0.11800000071525574, 0.18...
# intensities    585.0, 616.0, 731.0, 751.0, 881.0, 939.0, 903....
# x                                                        1.41726
# y                                                      -0.816841
# vx                                                      1.119772
# vy                                                      1.463632
# yaw                                                    -0.917724
# Name: 6325, dtype: object
# setid                                                          9
# lidar          0.08799999952316284, 0.11800000071525574, 0.18...
# intensities    585.0, 616.0, 731.0, 751.0, 881.0, 939.0, 903....
# x                                                        1.41726
# y                                                      -0.816841
# vx                                                      1.241093
# vy                                                      1.362276
# yaw                                                    -0.831913
# Name: 6326, dtype: object
# setid                                                          9
# lidar          0.06400000303983688, 0.09700000286102295, 0.13...
# intensities    573.0, 585.0, 621.0, 788.0, 983.0, 963.0, 863....
# x                                                       1.495676
# y                                                        -0.7039
# vx                                                      1.195711
# vy                                                      1.432054
# yaw                                                    -0.875098
# Name: 6327, dtype: object
# setid                                                          9
# lidar          0.06599999964237213, 0.14399999380111694, 0.21...
# intensities    566.0, 669.0, 803.0, 905.0, 1001.0, 948.0, 100...
# x                                                       1.532455
# y                                                      -0.566178
# vx                                                      1.378704
# vy                                                      1.256853
# yaw                                                    -0.739197
# Name: 6328, dtype: object
# setid                                                          9
# lidar          0.06599999964237213, 0.14399999380111694, 0.21...
# intensities    566.0, 669.0, 803.0, 905.0, 1001.0, 948.0, 100...
# x                                                       1.532455
# y                                                      -0.566178
# vx                                                      1.332629
# vy                                                      1.346933
# yaw                                                    -0.790737
# Name: 6329, dtype: object
# setid                                                          9
# lidar          0.052000001072883606, 0.061000000685453415, 0....
# intensities    557.0, 523.0, 500.0, 458.0, 444.0, 369.0, 321....
# x                                                       1.586443
# y                                                      -0.454128
# vx                                                       1.46634
# vy                                                       1.19999
# yaw                                                    -0.685835
# Name: 6330, dtype: object
# setid                                                          9
# lidar          0.052000001072883606, 0.061000000685453415, 0....
# intensities    557.0, 523.0, 500.0, 458.0, 444.0, 369.0, 321....
# x                                                       1.586443
# y                                                      -0.454128
# vx                                                      1.480562
# vy                                                      1.247322
# yaw                                                    -0.700104
# Name: 6331, dtype: object
# setid                                                          9
# lidar          0.06199999898672104, 0.05999999865889549, 0.06...
# intensities    554.0, 529.0, 517.0, 465.0, 427.0, 654.0, 671....
# x                                                        1.57716
# y                                                      -0.365459
# vx                                                       1.56442
# vy                                                      1.140379
# yaw                                                     -0.62989
# Name: 6332, dtype: object
# setid                                                          9
# lidar          0.06199999898672104, 0.05999999865889549, 0.06...
# intensities    554.0, 529.0, 517.0, 465.0, 427.0, 654.0, 671....
# x                                                        1.57716
# y                                                      -0.365459
# vx                                                      1.485497
# vy                                                      1.136416
# yaw                                                    -0.653037
# Name: 6333, dtype: object
# setid                                                          9
# lidar          0.06199999898672104, 0.05400000140070915, 0.05...
# intensities    544.0, 513.0, 495.0, 470.0, 456.0, 410.0, 637....
# x                                                       1.590219
# y                                                      -0.322637
# vx                                                      1.522325
# vy                                                      1.086586
# yaw                                                    -0.619906
# Name: 6334, dtype: object
# setid                                                          9
# lidar          0.06199999898672104, 0.05400000140070915, 0.05...
# intensities    544.0, 513.0, 495.0, 470.0, 456.0, 410.0, 637....
# x                                                       1.590219
# y                                                      -0.322637
# vx                                                      1.491334
# vy                                                      1.127077
# yaw                                                    -0.647172
# Name: 6335, dtype: object
# setid                                                          9
# lidar          0.057999998331069946, 0.054999999701976776, 0....
# intensities    561.0, 532.0, 496.0, 467.0, 434.0, 303.0, 900....
# x                                                       1.575713
# y                                                      -0.314707
# vx                                                      1.549414
# vy                                                        1.0458
# yaw                                                    -0.593726
# Name: 6336, dtype: object
# setid                                                          9
# lidar          0.057999998331069946, 0.054999999701976776, 0....
# intensities    561.0, 532.0, 496.0, 467.0, 434.0, 303.0, 900....
# x                                                       1.575713
# y                                                      -0.314707
# vx                                                      1.566383
# vy                                                      1.177628
# yaw                                                    -0.644661
# Name: 6337, dtype: object
# setid                                                          9
# lidar          0.07800000160932541, 0.11900000274181366, 0.20...
# intensities    567.0, 610.0, 755.0, 908.0, 865.0, 989.0, 1006...
# x                                                       1.538621
# y                                                      -0.317252
# vx                                                      1.605338
# vy                                                      1.123946
# yaw                                                    -0.610813
# Name: 6338, dtype: object
# setid                                                          9
# lidar          0.07800000160932541, 0.11900000274181366, 0.20...
# intensities    567.0, 610.0, 755.0, 908.0, 865.0, 989.0, 1006...
# x                                                       1.538621
# y                                                      -0.317252
# vx                                                       1.55383
# vy                                                      1.220993
# yaw                                                     -0.66602
# Name: 6339, dtype: object
# setid                                                          9
# lidar          0.10599999874830246, 0.17599999904632568, 0.19...
# intensities    616.0, 725.0, 718.0, 878.0, 879.0, 921.0, 1009...
# x                                                       1.507132
# y                                                      -0.375844
# vx                                                      1.493562
# vy                                                      1.278997
# yaw                                                    -0.708163
# Name: 6340, dtype: object
# setid                                                          9
# lidar          0.07500000298023224, 0.125, 0.1550000011920929...
# intensities    572.0, 630.0, 650.0, 819.0, 896.0, 894.0, 883....
# x                                                       1.475149
# y                                                      -0.444742
# vx                                                      1.488872
# vy                                                      1.347295
# yaw                                                    -0.735521
# Name: 6341, dtype: object
# setid                                                          9
# lidar          0.07500000298023224, 0.125, 0.1550000011920929...
# intensities    572.0, 630.0, 650.0, 819.0, 896.0, 894.0, 883....
# x                                                       1.475149
# y                                                      -0.444742
# vx                                                      1.465218
# vy                                                      1.378336
# yaw                                                    -0.754853
# Name: 6342, dtype: object
# setid                                                          9
# lidar          0.06700000166893005, 0.07100000232458115, 0.08...
# intensities    563.0, 554.0, 524.0, 799.0, 848.0, 961.0, 955....
# x                                                       1.434354
# y                                                       -0.52419
# vx                                                      1.419606
# vy                                                      1.424956
# yaw                                                    -0.787279
# Name: 6343, dtype: object
# setid                                                          9
# lidar          0.06700000166893005, 0.07100000232458115, 0.08...
# intensities    563.0, 554.0, 524.0, 799.0, 848.0, 961.0, 955....
# x                                                       1.434354
# y                                                       -0.52419
# vx                                                      1.382263
# vy                                                      1.517596
# yaw                                                    -0.832033
# Name: 6344, dtype: object
# setid                                                          9
# lidar          0.08100000023841858, 0.10300000011920929, 0.11...
# intensities    580.0, 580.0, 582.0, 780.0, 830.0, 861.0, 855....
# x                                                        1.42625
# y                                                      -0.634497
# vx                                                      1.371179
# vy                                                      1.527618
# yaw                                                    -0.839313
# Name: 6345, dtype: object
# setid                                                          9
# lidar          0.08100000023841858, 0.10300000011920929, 0.11...
# intensities    580.0, 580.0, 582.0, 780.0, 830.0, 861.0, 855....
# x                                                        1.42625
# y                                                      -0.634497
# vx                                                      1.291336
# vy                                                      1.577792
# yaw                                                    -0.884909
# Name: 6346, dtype: object
# setid                                                          9
# lidar          0.06800000369548798, 0.0860000029206276, 0.214...
# intensities    573.0, 579.0, 775.0, 933.0, 934.0, 862.0, 825....
# x                                                       1.353608
# y                                                      -0.644751
# vx                                                      1.277933
# vy                                                      1.588668
# yaw                                                    -0.893375
# Name: 6347, dtype: object
# 12696
